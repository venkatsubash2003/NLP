# %%
# !pip install nltk

# %%
sentence = "The Eiffel tower is was built from 1887 t 1889 by an French engineer named Gustave Eiffel, whose company specialized in building metal structures."
"""
Person Eg: Krish C Naik
Place or Location Eg: Hyderabad or Paris
Date Eg: September, 24-09-2023
Time Eg: 4:30pm
Money Eg: 1 million dollars
Organization Eg: Google
Percent Eg: 20%, twenty percent
"""
# Out:
# '\nPerson Eg: Krish C Naik\nPlace or Location Eg: Hyderabad or Paris\nDate Eg: September, 24-09-2023\nTime Eg: 4:30pm \nMoney Eg: 1 million dollars\nOrganization Eg: Google\nPercent Eg: 20%, twenty percent\n'

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize
words = word_tokenize(sentence)

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
tag_elements = nltk.pos_tag(words)

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
# nltk.ne_chunk(tag_elements).draw()
# we will get a graph after executing this
