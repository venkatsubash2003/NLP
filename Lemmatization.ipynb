# %%
# !pip install nltk

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer.lemmatize("going",pos="v")
# Out:
# 'go'

# %%
words = ["going","gone","programming","program","eat","ate","eaten","eating"]

# %%
for word in words:
  print(word + "--->" + lemmatizer.lemmatize(word,pos="v"))
  # By default the pos tag is set to 'n'
# Out:
# going--->go
# gone--->go
# programming--->program
# program--->program
# eat--->eat
# ate--->eat
# eaten--->eat
# eating--->eat

# %%
lemmatizer.lemmatize("goes",pos="v")
# Out:
# 'go'

# %%
lemmatizer.lemmatize("fairingly",pos="v")
# Out:
# 'fairingly'

# %%
lemmatizer.lemmatize("sportingly",pos="v")
# Out:
# 'sportingly'

# %%
## uSe cases of Lemmatization is Q and A Applications and Chatbots..
